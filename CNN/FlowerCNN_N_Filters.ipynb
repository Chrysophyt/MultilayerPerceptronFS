# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-f3ba816c-fad2-45cd-91b6-cd2fdcdd0750" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3ba816c-fad2-45cd-91b6-cd2fdcdd0750">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 72 bytes

# %% [markdown]
# # Dataset

# %%
import os
from kaggle.api.kaggle_api_extended import KaggleApi
from zipfile import ZipFile

def downloadFlowerData():
    '''Download flower detection dataset from alxmamaev/flowers-recognition.'''
    api = KaggleApi()
    api.authenticate()
    try:
        api.dataset_download_files('alxmamaev/flowers-recognition', path='data/',quiet=False) #do not forget to add kaggle.json into Users/.kaggle/
    except:
        return -1
    return 0

def checkDataset():
    # Check dataset zip file
    if(not os.path.exists('data/flowers-recognition.zip')):
        print("flowers dataset not found, downloading from kaggle")
        if(downloadFlowerData()==-1):
            print("Downloading dataset fail, please check kaggle.json is correct or try again with stable internet connection")
            os.remove('data/flowers-recognition.zip')
            quit()
    
    # Extract Data
    if(not os.path.exists('data/flowers/')):
        print("Extracting flowers-recognition.zip")
        with ZipFile('data/flowers-recognition.zip') as file:
            file.extractall('data/')
        print("Done")

import os, fnmatch
from PIL import Image
import numpy as np
import random

def convertToGrayscale(imageRGB):
    """return grayscale conversion of RGB image"""
    # https://docs.opencv.org/3.4/de/d25/imgproc_color_conversions.html
    # Basically  Grayscale = 0.299⋅R + 0.587⋅G + 0.114⋅B
    # We could easily vectorized and just do the dot product of imageRGB with [0.299,0.587,0.114]

    imageGrayscale = np.dot(imageRGB, [0.299,0.587,0.114])

    return imageGrayscale


def getImages(label, n=100):
    """return list of (default 100) images for a given label"""

    # Check Dataset
    checkDataset()

    # Try and get path
    path = "data/flowers/" + label.lower()
    if(not os.path.exists(path)):
        print("No label found")
        return -1
    
    # Get all images address
    allFiles = fnmatch.filter(os.listdir(path), '*.jpg')
    random.seed(42)
    usedFiles = random.sample(allFiles, n) # get 100 samples from allFiles

    # Read the data into numpy array
    imagesRGB = []
    for file in usedFiles:
        img = Image.open(path+'/'+file)
        img = img.resize((320,240), Image.ANTIALIAS)
        imagesRGB.append(np.asarray(img))
    
    imagesRGB = np.asarray(imagesRGB) #(n, 240, 320, 3)

    return imagesRGB

def preprocessImage(images): 
    """return np.array to be loaded into a model,
    flatten dimension (100, 240, 320) -> (100, 76800), and 
    Normalize data value from int [0, 255] -> float [0,1]"""

    x = images.reshape(*images.shape[:1], -1) #(100, 76800)
    x = x/255.0
    return x

# %% [markdown]
# # CNN Model

# %% [markdown]
# # Get Dataset

# %%
labels = ['Sunflower', 'Dandelion', 'Rose']
n_data = 100

X = None
y = None
for i in range(len(labels)):
    if(X is None):
        X = getImages(labels[i], n=n_data)
    else:
        X = np.append(X, getImages(labels[i], n=n_data), axis=0)

    if(y is None):
        y = np.full(shape=n_data,fill_value=i,dtype=np.int)
    else:
        y = np.append(y, np.full(shape=n_data,fill_value=i,dtype=np.int), axis=0)

# %%
from sklearn.model_selection import train_test_split
n_values = np.max(y) + 1
y = np.eye(n_values)[y]
print(y.shape)
X = X/255.0

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)
# Out:
# (300, 3)

# %% [markdown]
# ## Model 1

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(1),
    tf.keras.layers.Conv2D(8, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16),
    tf.keras.layers.Dense(3, activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics='acc')

# %%
history = model.fit(X_train, y_train, batch_size=5, epochs=30, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 48/48 [==============================] - 9s 172ms/step - loss: 26.3646 - acc: 0.4292 - val_loss: 6.9899 - val_acc: 0.4667
# Epoch 2/30
# 48/48 [==============================] - 8s 167ms/step - loss: 3.0518 - acc: 0.4750 - val_loss: 1.1940 - val_acc: 0.6167
# Epoch 3/30
# 48/48 [==============================] - 8s 165ms/step - loss: 1.3805 - acc: 0.5583 - val_loss: 1.0602 - val_acc: 0.4500
# Epoch 4/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.9857 - acc: 0.6083 - val_loss: 0.9877 - val_acc: 0.5333
# Epoch 5/30
# 48/48 [==============================] - 8s 165ms/step - loss: 0.9847 - acc: 0.5583 - val_loss: 1.0624 - val_acc: 0.5167
# Epoch 6/30
# 48/48 [==============================] - 8s 166ms/step - loss: 0.9141 - acc: 0.6167 - val_loss: 0.9789 - val_acc: 0.5833
# Epoch 7/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.9151 - acc: 0.6042 - val_loss: 0.8703 - val_acc: 0.5667
# Epoch 8/30
# 48/48 [==============================] - 8s 165ms/step - loss: 0.8718 - acc: 0.6083 - val_loss: 0.7890 - val_acc: 0.5667
# Epoch 9/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.9964 - acc: 0.5542 - val_loss: 0.9153 - val_acc: 0.5333
# Epoch 10/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.8368 - acc: 0.6292 - val_loss: 0.8039 - val_acc: 0.5500
# Epoch 11/30
# 48/48 [==============================] - 8s 165ms/step - loss: 0.7844 - acc: 0.6792 - val_loss: 0.7787 - val_acc: 0.6167
# Epoch 12/30
# 48/48 [==============================] - 8s 163ms/step - loss: 0.7740 - acc: 0.6625 - val_loss: 0.9067 - val_acc: 0.6333
# Epoch 13/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.7281 - acc: 0.6917 - val_loss: 0.7617 - val_acc: 0.6333
# Epoch 14/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.6780 - acc: 0.6708 - val_loss: 0.7817 - val_acc: 0.6500
# Epoch 15/30
# 48/48 [==============================] - 8s 165ms/step - loss: 0.6863 - acc: 0.7083 - val_loss: 0.7063 - val_acc: 0.6167
# Epoch 16/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.7037 - acc: 0.6875 - val_loss: 0.7120 - val_acc: 0.6833
# Epoch 17/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.7012 - acc: 0.6875 - val_loss: 0.7570 - val_acc: 0.6333
# Epoch 18/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.6392 - acc: 0.7167 - val_loss: 0.7049 - val_acc: 0.5833
# Epoch 19/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.6575 - acc: 0.7292 - val_loss: 0.7368 - val_acc: 0.6167
# Epoch 20/30
# 48/48 [==============================] - 8s 165ms/step - loss: 0.6304 - acc: 0.7167 - val_loss: 0.6971 - val_acc: 0.6167
# Epoch 21/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.6026 - acc: 0.7417 - val_loss: 0.8264 - val_acc: 0.6333
# Epoch 22/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.5965 - acc: 0.7375 - val_loss: 0.6796 - val_acc: 0.6500
# Epoch 23/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.5750 - acc: 0.7583 - val_loss: 0.9934 - val_acc: 0.6833
# Epoch 24/30
# 48/48 [==============================] - 8s 163ms/step - loss: 0.6030 - acc: 0.7750 - val_loss: 0.7514 - val_acc: 0.7000
# Epoch 25/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.6070 - acc: 0.7292 - val_loss: 0.8248 - val_acc: 0.6333
# Epoch 26/30
# 48/48 [==============================] - 8s 163ms/step - loss: 0.5714 - acc: 0.7250 - val_loss: 0.9340 - val_acc: 0.7000
# Epoch 27/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.6069 - acc: 0.7792 - val_loss: 0.7443 - val_acc: 0.7000
# Epoch 28/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.6888 - acc: 0.7208 - val_loss: 0.6842 - val_acc: 0.6500
# Epoch 29/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.5750 - acc: 0.7583 - val_loss: 0.9186 - val_acc: 0.6167
# Epoch 30/30
# 48/48 [==============================] - 8s 164ms/step - loss: 0.5432 - acc: 0.7708 - val_loss: 0.8369 - val_acc: 0.6333

# %% [markdown]
# ## Model 2

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(1),
    tf.keras.layers.Conv2D(16, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16),
    tf.keras.layers.Dense(3, activation='softmax')
])
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics='acc')

# %%
history2 = model2.fit(X_train, y_train, batch_size=5, epochs=30, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 48/48 [==============================] - 11s 207ms/step - loss: 5.6437 - acc: 0.4875 - val_loss: 1.2052 - val_acc: 0.7000
# Epoch 2/30
# 48/48 [==============================] - 10s 202ms/step - loss: 0.9117 - acc: 0.5917 - val_loss: 0.8025 - val_acc: 0.6833
# Epoch 3/30
# 48/48 [==============================] - 10s 201ms/step - loss: 0.8116 - acc: 0.6458 - val_loss: 0.9146 - val_acc: 0.5500
# Epoch 4/30
# 48/48 [==============================] - 10s 202ms/step - loss: 0.7668 - acc: 0.6750 - val_loss: 0.8303 - val_acc: 0.6333
# Epoch 5/30
# 48/48 [==============================] - 10s 202ms/step - loss: 0.8501 - acc: 0.7042 - val_loss: 0.8308 - val_acc: 0.6333
# Epoch 6/30
# 48/48 [==============================] - 10s 201ms/step - loss: 0.7721 - acc: 0.6708 - val_loss: 0.8172 - val_acc: 0.6333
# Epoch 7/30
# Epoch 29/30
# 48/48 [==============================] - 10s 201ms/step - loss: 0.5593 - acc: 0.7792 - val_loss: 0.9345 - val_acc: 0.6833
# Epoch 30/30
# 48/48 [==============================] - 10s 201ms/step - loss: 0.5032 - acc: 0.7875 - val_loss: 0.9834 - val_acc: 0.6333

# %% [markdown]
# ## Model 3

# %%
model3 = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(1),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16),
    tf.keras.layers.Dense(3, activation='softmax')
])
model3.compile(optimizer='adam', loss='categorical_crossentropy', metrics='acc')

# %%
history3 = model3.fit(X_train, y_train, batch_size=5, epochs=30, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 48/48 [==============================] - 14s 280ms/step - loss: 14.8921 - acc: 0.5333 - val_loss: 7.2417 - val_acc: 0.4167
# Epoch 2/30
# 48/48 [==============================] - 13s 269ms/step - loss: 2.1029 - acc: 0.5833 - val_loss: 1.5290 - val_acc: 0.5000
# Epoch 3/30
# 48/48 [==============================] - 13s 268ms/step - loss: 0.9645 - acc: 0.6625 - val_loss: 0.9964 - val_acc: 0.5500
# Epoch 4/30
# 48/48 [==============================] - 13s 267ms/step - loss: 1.0302 - acc: 0.6875 - val_loss: 0.9447 - val_acc: 0.5833
# Epoch 5/30
# 48/48 [==============================] - 13s 267ms/step - loss: 0.7666 - acc: 0.6875 - val_loss: 0.8448 - val_acc: 0.5667
# Epoch 6/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.7395 - acc: 0.7458 - val_loss: 0.8819 - val_acc: 0.5667
# Epoch 7/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.6539 - acc: 0.7833 - val_loss: 1.0595 - val_acc: 0.6167
# Epoch 8/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.6549 - acc: 0.7583 - val_loss: 0.8667 - val_acc: 0.5833
# Epoch 9/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.6375 - acc: 0.7583 - val_loss: 0.7787 - val_acc: 0.6500
# Epoch 10/30
# 48/48 [==============================] - 13s 267ms/step - loss: 0.6142 - acc: 0.7667 - val_loss: 0.8599 - val_acc: 0.6333
# Epoch 11/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.5857 - acc: 0.7833 - val_loss: 0.9918 - val_acc: 0.6333
# Epoch 12/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.6581 - acc: 0.7583 - val_loss: 0.8327 - val_acc: 0.6667
# Epoch 13/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.6423 - acc: 0.7667 - val_loss: 0.8766 - val_acc: 0.6167
# Epoch 14/30
# 48/48 [==============================] - 13s 269ms/step - loss: 0.5614 - acc: 0.7958 - val_loss: 1.2575 - val_acc: 0.6333
# Epoch 15/30
# 48/48 [==============================] - 13s 267ms/step - loss: 0.5352 - acc: 0.8167 - val_loss: 1.3544 - val_acc: 0.5833
# Epoch 16/30
# 48/48 [==============================] - 13s 268ms/step - loss: 0.5835 - acc: 0.7875 - val_loss: 1.0345 - val_acc: 0.6667
# Epoch 17/30
# 48/48 [==============================] - 13s 265ms/step - loss: 0.5752 - acc: 0.7750 - val_loss: 0.8481 - val_acc: 0.6833
# Epoch 18/30
# 48/48 [==============================] - 13s 267ms/step - loss: 0.4830 - acc: 0.8042 - val_loss: 0.7796 - val_acc: 0.6833
# Epoch 19/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.5056 - acc: 0.7917 - val_loss: 1.1011 - val_acc: 0.5833
# Epoch 20/30
# 48/48 [==============================] - 13s 265ms/step - loss: 0.5263 - acc: 0.8208 - val_loss: 0.9161 - val_acc: 0.5667
# Epoch 21/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.5212 - acc: 0.8042 - val_loss: 0.9238 - val_acc: 0.6000
# Epoch 22/30
# 48/48 [==============================] - 13s 267ms/step - loss: 0.4848 - acc: 0.8417 - val_loss: 1.3484 - val_acc: 0.6000
# Epoch 23/30
# 48/48 [==============================] - 13s 267ms/step - loss: 0.4768 - acc: 0.8125 - val_loss: 0.9112 - val_acc: 0.6167
# Epoch 24/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.5775 - acc: 0.8042 - val_loss: 0.8827 - val_acc: 0.6167
# Epoch 25/30
# 48/48 [==============================] - 13s 268ms/step - loss: 0.5113 - acc: 0.8042 - val_loss: 0.8561 - val_acc: 0.6500
# Epoch 26/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.4906 - acc: 0.8333 - val_loss: 1.2168 - val_acc: 0.6167
# Epoch 27/30
# 48/48 [==============================] - 13s 267ms/step - loss: 0.5126 - acc: 0.8083 - val_loss: 0.9836 - val_acc: 0.6833
# Epoch 28/30
# 48/48 [==============================] - 13s 266ms/step - loss: 0.4860 - acc: 0.8167 - val_loss: 0.8960 - val_acc: 0.6167
# Epoch 29/30
# 48/48 [==============================] - 13s 267ms/step - loss: 0.5543 - acc: 0.7917 - val_loss: 0.9534 - val_acc: 0.6500
# Epoch 30/30
# 48/48 [==============================] - 13s 267ms/step - loss: 0.5293 - acc: 0.7875 - val_loss: 1.0333 - val_acc: 0.6167

# %% [markdown]
# ## Model 4

# %%
model4 = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(1),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16),
    tf.keras.layers.Dense(3, activation='softmax')
])
model4.compile(optimizer='adam', loss='categorical_crossentropy', metrics='acc')

# %%
history4 = model4.fit(X_train, y_train, batch_size=5, epochs=30, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 48/48 [==============================] - 23s 458ms/step - loss: 25.7016 - acc: 0.4667 - val_loss: 2.3736 - val_acc: 0.6500
# Epoch 2/30
# 48/48 [==============================] - 21s 434ms/step - loss: 1.0705 - acc: 0.6625 - val_loss: 0.8671 - val_acc: 0.6833
# Epoch 3/30
# 48/48 [==============================] - 21s 431ms/step - loss: 0.8146 - acc: 0.7083 - val_loss: 0.8120 - val_acc: 0.6167
# Epoch 4/30
# 48/48 [==============================] - 21s 429ms/step - loss: 0.7477 - acc: 0.6792 - val_loss: 0.7263 - val_acc: 0.6667
# Epoch 5/30
# 48/48 [==============================] - 20s 426ms/step - loss: 0.4931 - acc: 0.8083 - val_loss: 0.9926 - val_acc: 0.7667
# Epoch 27/30
# 48/48 [==============================] - 20s 425ms/step - loss: 0.5477 - acc: 0.8042 - val_loss: 1.3461 - val_acc: 0.7000
# Epoch 28/30
# 48/48 [==============================] - 20s 426ms/step - loss: 0.4731 - acc: 0.8125 - val_loss: 0.8608 - val_acc: 0.6833
# Epoch 29/30
# 48/48 [==============================] - 21s 428ms/step - loss: 0.4388 - acc: 0.8208 - val_loss: 1.0329 - val_acc: 0.7167
# Epoch 30/30
# 48/48 [==============================] - 21s 428ms/step - loss: 0.5012 - acc: 0.8000 - val_loss: 1.0721 - val_acc: 0.7000

# %% [markdown]
# ## Model 5

# %%
model5 = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(1),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16),
    tf.keras.layers.Dense(3, activation='softmax')
])
model5.compile(optimizer='adam', loss='categorical_crossentropy', metrics='acc')

history5 = model5.fit(X_train, y_train, batch_size=5, epochs=30, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 48/48 [==============================] - 39s 777ms/step - loss: 29.1982 - acc: 0.5042 - val_loss: 1.7445 - val_acc: 0.6000
# Epoch 2/30
# 48/48 [==============================] - 36s 753ms/step - loss: 1.1784 - acc: 0.6458 - val_loss: 0.7386 - val_acc: 0.6833
# Epoch 3/30
# 48/48 [==============================] - 36s 749ms/step - loss: 0.7798 - acc: 0.6875 - val_loss: 0.7217 - val_acc: 0.6167
# Epoch 4/30
# 48/48 [==============================] - 36s 746ms/step - loss: 0.8016 - acc: 0.6792 - val_loss: 0.7510 - val_acc: 0.6833
# Epoch 5/30
# 48/48 [==============================] - 36s 750ms/step - loss: 0.7593 - acc: 0.7042 - val_loss: 0.7277 - val_acc: 0.7167
# Epoch 6/30
# 48/48 [==============================] - 36s 748ms/step - loss: 0.6771 - acc: 0.7333 - val_loss: 0.7031 - val_acc: 0.7667
# Epoch 7/30
# 48/48 [==============================] - 36s 751ms/step - loss: 0.6022 - acc: 0.7375 - val_loss: 0.6358 - val_acc: 0.7333
# Epoch 8/30
# 48/48 [==============================] - 36s 749ms/step - loss: 0.5876 - acc: 0.7417 - val_loss: 0.7505 - val_acc: 0.7167
# Epoch 9/30
# 48/48 [==============================] - 36s 748ms/step - loss: 0.6302 - acc: 0.7375 - val_loss: 0.7042 - val_acc: 0.7167
# Epoch 10/30
# 48/48 [==============================] - 36s 749ms/step - loss: 0.6180 - acc: 0.7333 - val_loss: 0.6125 - val_acc: 0.6833
# Epoch 11/30
# 48/48 [==============================] - 36s 748ms/step - loss: 0.5925 - acc: 0.7500 - val_loss: 0.7145 - val_acc: 0.7000
# Epoch 12/30
# 48/48 [==============================] - 36s 745ms/step - loss: 0.5941 - acc: 0.7458 - val_loss: 0.8992 - val_acc: 0.7000
# Epoch 13/30
# 48/48 [==============================] - 36s 745ms/step - loss: 0.5925 - acc: 0.7000 - val_loss: 0.7721 - val_acc: 0.6833
# Epoch 14/30
# 48/48 [==============================] - 36s 745ms/step - loss: 0.6130 - acc: 0.7750 - val_loss: 1.0550 - val_acc: 0.6000
# Epoch 15/30
# 48/48 [==============================] - 36s 744ms/step - loss: 0.5936 - acc: 0.7250 - val_loss: 1.0487 - val_acc: 0.6833
# Epoch 16/30
# 48/48 [==============================] - 36s 747ms/step - loss: 0.6025 - acc: 0.7625 - val_loss: 0.9939 - val_acc: 0.6833
# Epoch 17/30
# 48/48 [==============================] - 36s 749ms/step - loss: 0.5568 - acc: 0.7917 - val_loss: 0.8639 - val_acc: 0.7000
# Epoch 18/30
# 48/48 [==============================] - 36s 746ms/step - loss: 0.5813 - acc: 0.7750 - val_loss: 1.0207 - val_acc: 0.7167
# Epoch 19/30
# 48/48 [==============================] - 36s 746ms/step - loss: 0.6333 - acc: 0.7792 - val_loss: 0.7747 - val_acc: 0.7167
# Epoch 20/30
# 48/48 [==============================] - 36s 743ms/step - loss: 0.5580 - acc: 0.8083 - val_loss: 0.7794 - val_acc: 0.6667
# Epoch 21/30
# 48/48 [==============================] - 36s 746ms/step - loss: 0.5262 - acc: 0.7875 - val_loss: 1.0459 - val_acc: 0.7167
# Epoch 22/30
# 48/48 [==============================] - 36s 745ms/step - loss: 0.6681 - acc: 0.7917 - val_loss: 0.8688 - val_acc: 0.7000
# Epoch 23/30
# 48/48 [==============================] - 37s 767ms/step - loss: 0.5676 - acc: 0.7792 - val_loss: 0.9824 - val_acc: 0.6500
# Epoch 24/30
# 48/48 [==============================] - 36s 743ms/step - loss: 0.6211 - acc: 0.7583 - val_loss: 0.9301 - val_acc: 0.6500
# Epoch 25/30
# 48/48 [==============================] - 36s 743ms/step - loss: 0.6707 - acc: 0.7750 - val_loss: 1.2232 - val_acc: 0.6333
# Epoch 26/30
# 48/48 [==============================] - 36s 742ms/step - loss: 0.6937 - acc: 0.7083 - val_loss: 0.8064 - val_acc: 0.6667
# Epoch 27/30
# 48/48 [==============================] - 36s 744ms/step - loss: 0.5575 - acc: 0.7958 - val_loss: 0.8371 - val_acc: 0.6833
# Epoch 28/30
# 48/48 [==============================] - 36s 743ms/step - loss: 0.9103 - acc: 0.6792 - val_loss: 0.8054 - val_acc: 0.6667
# Epoch 29/30
# 48/48 [==============================] - 36s 744ms/step - loss: 0.7385 - acc: 0.7500 - val_loss: 0.8276 - val_acc: 0.6500
# Epoch 30/30
# 48/48 [==============================] - 36s 756ms/step - loss: 0.6171 - acc: 0.8083 - val_loss: 0.8509 - val_acc: 0.6667

# %% [markdown]
# ## Plot

# %%
# !pip install -q git+https://github.com/tensorflow/docs

import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots
# Out:
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
models_histories = {'n_filters_08':history,'n_filters_16':history2,'n_filters_32':history3, 'n_filters_64':history4, 'n_filters_128':history5}

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'acc', smoothing_std=1)
figure(figsize=(15, 10), dpi=80)

plotter.plot(models_histories)

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'loss', smoothing_std=1)
figure(figsize=(15, 10), dpi=80)
plt.ylim([0, 2])
plotter.plot(models_histories)
